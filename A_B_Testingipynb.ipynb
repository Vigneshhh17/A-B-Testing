# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshhh17/A-B-Testing/blob/main/A_B_Testingipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/WA_Fn-UseC_-Marketing-Campaign-Eff-UseC_-FastF.csv"
df = pd.read_csv(file_name)

df.head(10)
# Out:
#    MarketID MarketSize  LocationID  AgeOfStore  Promotion  week  \
# 0         1     Medium           1           4          3     1
# 1         1     Medium           1           4          3     2
# 2         1     Medium           1           4          3     3
# 3         1     Medium           1           4          3     4
# 4         1     Medium           2           5          2     1
# 5         1     Medium           2           5          2     2
# 6         1     Medium           2           5          2     3
# 7         1     Medium           2           5          2     4
# 8         1     Medium           3          12          1     1
# 9         1     Medium           3          12          1     2
#
#    SalesInThousands
# 0             33.73
# 1             35.67
# 2             29.03
# 3             39.25
# 4             27.81
# 5             34.67
# 6             27.98
# 7             27.72
# 8             44.54
# 9             37.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MarketID          548 non-null    int64
#  1   MarketSize        548 non-null    object
#  2   LocationID        548 non-null    int64
#  3   AgeOfStore        548 non-null    int64
#  4   Promotion         548 non-null    int64
#  5   week              548 non-null    int64
#  6   SalesInThousands  548 non-null    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 30.1+ KB

# %%
df.describe()
# Out:
#          MarketID  LocationID  AgeOfStore   Promotion        week  \
# count  548.000000  548.000000  548.000000  548.000000  548.000000
# mean     5.715328  479.656934    8.503650    2.029197    2.500000
# std      2.877001  287.973679    6.638345    0.810729    1.119055
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000  216.000000    4.000000    1.000000    1.750000
# 50%      6.000000  504.000000    7.000000    2.000000    2.500000
# 75%      8.000000  708.000000   12.000000    3.000000    3.250000
# max     10.000000  920.000000   28.000000    3.000000    4.000000
#
#        SalesInThousands
# count        548.000000
# mean          53.466204
# std           16.755216
# min           17.340000
# 25%           42.545000
# 50%           50.200000
# 75%           60.477500
# max           99.650000

# %%
df.isnull().sum().sort_values(ascending=False) #No missing values in the dataset
# Out:
# MarketID            0
# MarketSize          0
# LocationID          0
# AgeOfStore          0
# Promotion           0
# week                0
# SalesInThousands    0
# dtype: int64

# %%
# Using ggplot style
plt.style.use('ggplot')
ax = df.groupby('Promotion').sum()['SalesInThousands'].plot.pie(figsize=(8,8),
                                                                autopct='%1.0f%%',shadow=True,explode = (0, 0.1, 0))
ax.set_ylabel('')
ax.set_title('Sales Distribution Across the 3 Different Promotions')

plt.show()

# %%
#promotion for each market size
df.groupby(['Promotion', 'MarketSize']).count()['MarketID']
# Out:
# Promotion  MarketSize
# 1          Large          56
#            Medium         96
#            Small          20
# 2          Large          64
#            Medium        108
#            Small          16
# 3          Large          48
#            Medium        116
#            Small          24
# Name: MarketID, dtype: int64

# %%
# Using unstack
df.groupby(['Promotion', 'MarketSize']).count()['MarketID'].unstack('MarketSize')
# Out:
# MarketSize  Large  Medium  Small
# Promotion
# 1              56      96     20
# 2              64     108     16
# 3              48     116     24

# %%
# Put this into a plot
ax = df.groupby(['Promotion', 'MarketSize']).count()['MarketID'].unstack('MarketSize').plot(
    kind='bar',
    figsize=(12,10),
    grid=True)

ax.set_ylabel('count')
ax.set_title('breakdowns of market sizes across different promotions')
plt.show()

# %%
 #Putting this into a different plot
ax = df.groupby(['Promotion', 'MarketSize']).count()['MarketID'].unstack('MarketSize').plot(
    kind='bar',
    figsize=(12,10),
    grid=True,
    stacked=True)

ax.set_ylabel('count')
ax.set_title('breakdowns of market sizes across different promotions')

plt.show()

# %%
ax = df.groupby('AgeOfStore').count()['MarketID'].plot(
    kind='bar',
    figsize=(12,7),
    grid=True)

ax.set_xlabel('age')
ax.set_ylabel('count')
ax.set_title('Overall Distributions Store Ages')

plt.show()

# %%
#Group by Age of Store and Promotion to get counts
df.groupby(['AgeOfStore', 'Promotion']).count()['MarketID']
# Out:
# AgeOfStore  Promotion
# 1           1            24
#             2            36
#             3            20
# 2           1             8
#             2             8
#             3             4
# 3           1            16
#             2            12
#             3             4
# 4           1            16
#             2            12
#             3            16
# 5           1             8
#             2            12
#             3            24
# 6           1            20
#             2             4
#             3            12
# 7           1             4
#             2            24
#             3            12
# 8           1            12
#             2             8
#             3            20
# 9           1             8
#             2            12
#             3             8
# 10          2            16
#             3             8
# 11          1             4
#             3            12
# 12          1            12
#             2             4
#             3             8
# 13          1            12
#             2             8
# 14          2             8
#             3             4
# 15          1             4
#             2             4
# 17          3             4
# 18          1             8
# 19          1             4
#             2             8
#             3             8
# 20          3             4
# 22          1             4
#             3             8
# 23          2             4
#             3             4
# 24          1             4
#             3             8
# 25          2             4
# 27          1             4
# 28          2             4
# Name: MarketID, dtype: int64

# %%
# Visaulize
ax = df.groupby(['AgeOfStore', 'Promotion']).count()['MarketID'].unstack('Promotion').iloc[::-1].plot(
    kind='barh',
    figsize=(14,18),
    grid=True)

ax.set_ylabel('age')
ax.set_xlabel('count')
ax.set_title('overall distributions of age of store')

plt.show()

# %% [markdown]
# **Performing A/B test**

# %%
df['SalesInThousands'] = pd.to_numeric(df['SalesInThousands'], errors='coerce')
means = df.groupby('Promotion')['SalesInThousands'].mean()
stds = df.groupby('Promotion')['SalesInThousands'].std()
ns = df.groupby('Promotion')['SalesInThousands'].count()

print(means)
print(stds)
print(ns)
# Out:
# Promotion
# 1    58.099012
# 2    47.329415
# 3    55.364468
# Name: SalesInThousands, dtype: float64
# Promotion
# 1    16.553782
# 2    15.108955
# 3    16.766231
# Name: SalesInThousands, dtype: float64
# Promotion
# 1    172
# 2    188
# 3    188
# Name: SalesInThousands, dtype: int64

# %% [markdown]
# COMPARING PROMOTION 1 AND 2 using p and t value analysis

# %%
# Computing the t and p values using scipy
from scipy import stats

t, p = stats.ttest_ind(df.loc[df['Promotion'] == 1, 'SalesInThousands'].values,
                       df.loc[df['Promotion'] == 2, 'SalesInThousands'].values,
                       equal_var=False)
print("t-value = " +str(t))
print("p-value = " +str(p))
# Out:
# t-value = 6.42752867090748
# p-value = 4.2903687179871785e-10

# %% [markdown]
# Comparing 1 and 3

# %%
from scipy import stats

t, p = stats.ttest_ind(df.loc[df['Promotion'] == 1, 'SalesInThousands'].values,
                       df.loc[df['Promotion'] == 3, 'SalesInThousands'].values,
                       equal_var=False)
print("t-value = " +str(t))
print("p-value = " +str(p))
# Out:
# t-value = 1.5560224307758634
# p-value = 0.12059147742229478

# %%
#Conclusion from P and T values
We note that the average sales from promotion group 1 (58.1) is  higher than those from promotion group 2 (55.36).
 But, running a t-test between these two groups, gives us a t-value of 1.556 and a p-value of 0.121.
 The computed **p-value is a lot higher than 0.05**, past the threshold for statistical significance.
